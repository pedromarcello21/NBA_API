# %% [markdown]
# This notebook demonstrates the capabilities of Rapid AI's "NBA API".  This API retrives season, team, and player data from the NBA and is a great tool to quickly gather statistics for many instances.

# %% [markdown]
# You can find the NBA API [here](https://rapidapi.com/api-sports/api/api-nba) where you'll receive an API key after creating an account on https://rapidapi.com/hub

# %% [markdown]
# [Here's](https://api-sports.io/documentation/nba/v2) the documentation for the NBA API that articulates on possible queries and their parameters.

# %%
#Import relevant packages
import os
from dotenv import load_dotenv
import http.client
import requests
import json

# %%
# Load all of the environment variables in the .env file
load_dotenv()

# Retrieve the environment variable with the name NBA_API_KEY
my_api_key = os.getenv("NBA_API_KEY")

if not my_api_key:
  print("WARNING: NBA API key not found")
else:
  print("Successfully retrieved NBA API key")
# Out:
# Successfully retrieved NBA API key

# %% [markdown]
# Let's take a look at the available seasons we can request data for.  It looks like we won't be able to get any stats on some legends like Pat Ewing or Larry Johnson :/

# %%
# Establish API connection
conn = http.client.HTTPSConnection("api-nba-v1.p.rapidapi.com")

#Define headers for NBA API on rapid api
headers = {
    'X-RapidAPI-Key': my_api_key,
    'X-RapidAPI-Host': "api-nba-v1.p.rapidapi.com"
}
#Send a request to the API to get the available seasons
conn.request("GET", "/seasons", headers=headers)

#Get and read the response
res = conn.getresponse()
data = res.read()

# Parse the JSON string into a Python object
data_json = json.loads(data)

# Print JSON respnose data
print(json.dumps(data_json['response'], indent=2))
# Out:
# [
#   2015,
#   2016,
#   2017,
#   2018,
#   2019,
#   2020,
#   2021,
#   2022,
#   2023
# ]

# %% [markdown]
# Let's search for an active player and get some of his background data

# %%
#Send a request to the API to get player info
conn.request("GET", "/players?search=Brunson", headers=headers)

res = conn.getresponse()
data = res.read()
# Decode bytes to string

# Parse the JSON string into a Python object
data_json = json.loads(data)
print(json.dumps(data_json['response'], indent=2))  # Pretty print JSON data
# Out:
# [
#   {
#     "id": 946,
#     "firstname": "Jalen",
#     "lastname": "Brunson",
#     "birth": {
#       "date": "1996-08-31",
#       "country": "USA"
#     },
#     "nba": {
#       "start": 2018,
#       "pro": 3
#     },
#     "height": {
#       "feets": "6",
#       "inches": "1",
#       "meters": "1.85"
#     },
#     "weight": {
#       "pounds": "190",
#       "kilograms": "86.2"
#     },
#     "college": "Villanova",
#     "affiliation": "Villanova/USA",
#     "leagues": {
#       "standard": {
#         "jersey": 11,
#         "active": true,
#         "pos": "G"
#       },
#       "vegas": {
#         "jersey": 13,
#         "active": true,
#         "pos": "G"
#       }
#     }
#   }
# ]

# %% [markdown]
# Let's look up the home team

# %%
#Get data about teams
conn.request("GET", "/teams?search=Knicks&league=standard", headers=headers)

res = conn.getresponse()
data = res.read()
data_json = json.loads(data)
test = json.dumps(data_json['response'], indent=2)  # Pretty print JSON data
print(test)
# Out:
# [
#   {
#     "id": 24,
#     "name": "New York Knicks",
#     "nickname": "Knicks",
#     "code": "NYK",
#     "city": "New York",
#     "logo": "https://upload.wikimedia.org/wikipedia/fr/3/34/Knicks_de_NY.png",
#     "allStar": false,
#     "nbaFranchise": true,
#     "leagues": {
#       "standard": {
#         "conference": "East",
#         "division": "Atlantic"
#       }
#     }
#   }
# ]

# %% [markdown]
# Let's look up the current standings in the NBA

# %%
conn.request("GET", "/standings?league=standard&season=2023", headers=headers)

res = conn.getresponse()
data = res.read()

data.decode("utf-8")
data_json = json.loads(data)
test = data_json['response']

for key in test:
   print(key['team']['name'], key['conference'])
# Out:
# Boston Celtics {'name': 'east', 'rank': 1, 'win': 11, 'loss': 2}
# Philadelphia 76ers {'name': 'east', 'rank': 2, 'win': 10, 'loss': 3}
# New York Knicks {'name': 'east', 'rank': 4, 'win': 8, 'loss': 5}
# Brooklyn Nets {'name': 'east', 'rank': 11, 'win': 6, 'loss': 7}
# Toronto Raptors {'name': 'east', 'rank': 10, 'win': 6, 'loss': 7}
# Milwaukee Bucks {'name': 'east', 'rank': 3, 'win': 9, 'loss': 4}
# Indiana Pacers {'name': 'east', 'rank': 7, 'win': 7, 'loss': 5}
# Cleveland Cavaliers {'name': 'east', 'rank': 8, 'win': 7, 'loss': 6}
# Chicago Bulls {'name': 'east', 'rank': 12, 'win': 5, 'loss': 9}
# Detroit Pistons {'name': 'east', 'rank': 15, 'win': 2, 'loss': 12}
# Miami Heat {'name': 'east', 'rank': 6, 'win': 8, 'loss': 5}
# Orlando Magic {'name': 'east', 'rank': 5, 'win': 8, 'loss': 5}
# Atlanta Hawks {'name': 'east', 'rank': 9, 'win': 6, 'loss': 6}
# Charlotte Hornets {'name': 'east', 'rank': 13, 'win': 3, 'loss': 9}
# Washington Wizards {'name': 'east', 'rank': 14, 'win': 2, 'loss': 10}
# Minnesota Timberwolves {'name': 'west', 'rank': 1, 'win': 9, 'loss': 3}
# Oklahoma City Thunder {'name': 'west', 'rank': 2, 'win': 10, 'loss': 4}
# Denver Nuggets {'name': 'west', 'rank': 3, 'win': 9, 'loss': 4}
# Utah Jazz {'name': 'west', 'rank': 12, 'win': 4, 'loss': 9}
# Portland Trail Blazers {'name': 'west', 'rank': 14, 'win': 3, 'loss': 10}
# Sacramento Kings {'name': 'west', 'rank': 4, 'win': 8, 'loss': 4}
# Los Angeles Lakers {'name': 'west', 'rank': 6, 'win': 8, 'loss': 6}
# Phoenix Suns {'name': 'west', 'rank': 8, 'win': 7, 'loss': 6}
# Golden State Warriors {'name': 'west', 'rank': 10, 'win': 6, 'loss': 8}
# LA Clippers {'name': 'west', 'rank': 11, 'win': 4, 'loss': 7}
# Dallas Mavericks {'name': 'west', 'rank': 5, 'win': 9, 'loss': 5}
# Houston Rockets {'name': 'west', 'rank': 7, 'win': 6, 'loss': 5}
# New Orleans Pelicans {'name': 'west', 'rank': 9, 'win': 6, 'loss': 7}
# Memphis Grizzlies {'name': 'west', 'rank': 13, 'win': 3, 'loss': 10}
# San Antonio Spurs {'name': 'west', 'rank': 15, 'win': 3, 'loss': 10}

# %% [markdown]
# Let's get the games that were played on Nov 19 2023

# %%
# Get data from games played in NBA on November 19 2023
conn.request("GET", "/games/?league=standard&date=2023-11-19&season=2023", headers=headers)

res = conn.getresponse()
data = res.read()

# # Decode bytes to string
# data_str = data.decode('utf-8')

# Parse the JSON string into a Python object
data_json = json.loads(data)
print(json.dumps(data_json['response'], indent=2))  # Pretty print JSON data
# Out:
# [
#   {
#     "id": 12728,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T00:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Smoothie King Center",
#       "city": "New Orleans",
#       "state": "LA",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 22,
#         "name": "Minnesota Timberwolves",
#         "nickname": "Timberwolves",
#         "code": "MIN",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png"
#       },
#       "home": {
#         "id": 23,
#         "name": "New Orleans Pelicans",
#         "nickname": "Pelicans",
#         "code": "NOP",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "27",
#           "32",
#           "26",
#           "36"
#         ],
#         "points": 121
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "35",
#           "29",
#           "31",
#           "25"
#         ],
#         "points": 120
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12729,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T01:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "United Center",
#       "city": "Chicago",
#       "state": "IL",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 20,
#         "name": "Miami Heat",
#         "nickname": "Heat",
#         "code": "MIA",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/1/1c/Miami_Heat_-_Logo.svg/1200px-Miami_Heat_-_Logo.svg.png"
#       },
#       "home": {
#         "id": 6,
#         "name": "Chicago Bulls",
#         "nickname": "Bulls",
#         "code": "CHI",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/d1/Bulls_de_Chicago_logo.svg/1200px-Bulls_de_Chicago_logo.svg.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "26",
#           "24",
#           "26",
#           "21"
#         ],
#         "points": 97
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "14",
#           "26",
#           "28",
#           "34"
#         ],
#         "points": 102
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12730,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T01:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Fiserv Forum",
#       "city": "Milwaukee",
#       "state": "WI",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 8,
#         "name": "Dallas Mavericks",
#         "nickname": "Mavericks",
#         "code": "DAL",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/b/b8/Mavericks_de_Dallas_logo.svg/150px-Mavericks_de_Dallas_logo.svg.png"
#       },
#       "home": {
#         "id": 21,
#         "name": "Milwaukee Bucks",
#         "nickname": "Bucks",
#         "code": "MIL",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/3/34/Bucks2015.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "34",
#           "24",
#           "40",
#           "27"
#         ],
#         "points": 125
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "33",
#           "27",
#           "29",
#           "43"
#         ],
#         "points": 132
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12731,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T01:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Frost Bank Center",
#       "city": "San Antonio",
#       "state": "TX",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 19,
#         "name": "Memphis Grizzlies",
#         "nickname": "Grizzlies",
#         "code": "MEM",
#         "logo": "https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png"
#       },
#       "home": {
#         "id": 31,
#         "name": "San Antonio Spurs",
#         "nickname": "Spurs",
#         "code": "SAS",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/0/0e/San_Antonio_Spurs_2018.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "26",
#           "25",
#           "36",
#           "33"
#         ],
#         "points": 120
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "35",
#           "33",
#           "26",
#           "14"
#         ],
#         "points": 108
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12732,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T01:30:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Chase Center",
#       "city": "San Francisco",
#       "state": "CA",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 25,
#         "name": "Oklahoma City Thunder",
#         "nickname": "Thunder",
#         "code": "OKC",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/4/4f/Thunder_d%27Oklahoma_City_logo.svg/1200px-Thunder_d%27Oklahoma_City_logo.svg.png"
#       },
#       "home": {
#         "id": 11,
#         "name": "Golden State Warriors",
#         "nickname": "Warriors",
#         "code": "GSW",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "33",
#           "18",
#           "34",
#           "32",
#           "13"
#         ],
#         "points": 130
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "31",
#           "30",
#           "26",
#           "30",
#           "6"
#         ],
#         "points": 123
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12733,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T20:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Barclays Center",
#       "city": "Brooklyn",
#       "state": "NY",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 27,
#         "name": "Philadelphia 76ers",
#         "nickname": "76ers",
#         "code": "PHI",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/4/48/76ers_2016.png"
#       },
#       "home": {
#         "id": 4,
#         "name": "Brooklyn Nets",
#         "nickname": "Nets",
#         "code": "BKN",
#         "logo": "https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Brooklyn_Nets_newlogo.svg/130px-Brooklyn_Nets_newlogo.svg.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "23",
#           "38",
#           "33",
#           "27"
#         ],
#         "points": 121
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "22",
#           "27",
#           "22",
#           "28"
#         ],
#         "points": 99
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12734,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T21:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Scotiabank Arena",
#       "city": "Toronto",
#       "state": "ON",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 10,
#         "name": "Detroit Pistons",
#         "nickname": "Pistons",
#         "code": "DET",
#         "logo": "https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Logo_of_the_Detroit_Pistons.png/300px-Logo_of_the_Detroit_Pistons.png"
#       },
#       "home": {
#         "id": 38,
#         "name": "Toronto Raptors",
#         "nickname": "Raptors",
#         "code": "TOR",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/8/89/Raptors2015.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "20",
#           "25",
#           "27",
#           "41"
#         ],
#         "points": 113
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "32",
#           "37",
#           "35",
#           "38"
#         ],
#         "points": 142
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12735,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T22:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Gainbridge Fieldhouse",
#       "city": "Indianapolis",
#       "state": "IN",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 26,
#         "name": "Orlando Magic",
#         "nickname": "Magic",
#         "code": "ORL",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/b/bd/Orlando_Magic_logo_2010.png"
#       },
#       "home": {
#         "id": 15,
#         "name": "Indiana Pacers",
#         "nickname": "Pacers",
#         "code": "IND",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/c/cf/Pacers_de_l%27Indiana_logo.svg/1180px-Pacers_de_l%27Indiana_logo.svg.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "42",
#           "36",
#           "29",
#           "21"
#         ],
#         "points": 128
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "21",
#           "23",
#           "34",
#           "38"
#         ],
#         "points": 116
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12736,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-19T23:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": null,
#       "halftime": false,
#       "short": 3,
#       "long": "Finished"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Rocket Mortgage FieldHouse",
#       "city": "Cleveland",
#       "state": "OH",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 9,
#         "name": "Denver Nuggets",
#         "nickname": "Nuggets",
#         "code": "DEN",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/3/35/Nuggets_de_Denver_2018.png/180px-Nuggets_de_Denver_2018.png"
#       },
#       "home": {
#         "id": 7,
#         "name": "Cleveland Cavaliers",
#         "nickname": "Cavaliers",
#         "code": "CLE",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/0/06/Cavs_de_Cleveland_logo_2017.png/150px-Cavs_de_Cleveland_logo_2017.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "27",
#           "31",
#           "17",
#           "34"
#         ],
#         "points": 109
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "29",
#           "37",
#           "26",
#           "29"
#         ],
#         "points": 121
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   }
# ]

# %% [markdown]
# Let's look at the games happening live.  Empty list means no games are currently on

# %%
conn.request("GET", "/games?live=all", headers=headers)

res = conn.getresponse()
data = res.read()
data_json = json.loads(data)
print(json.dumps(data_json['response'], indent=2))  # Pretty print JSON data
# Out:
# [
#   {
#     "id": 12742,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-21T00:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": "6:06",
#       "halftime": false,
#       "short": 2,
#       "long": "In Play"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Spectrum Center",
#       "city": "Charlotte",
#       "state": "NC",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 2,
#         "name": "Boston Celtics",
#         "nickname": "Celtics",
#         "code": "BOS",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/6/65/Celtics_de_Boston_logo.svg/1024px-Celtics_de_Boston_logo.svg.png"
#       },
#       "home": {
#         "id": 5,
#         "name": "Charlotte Hornets",
#         "nickname": "Hornets",
#         "code": "CHA",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/f/f3/Hornets_de_Charlotte_logo.svg/1200px-Hornets_de_Charlotte_logo.svg.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "31",
#           "34",
#           "22",
#           "13"
#         ],
#         "points": 100
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "25",
#           "29",
#           "27",
#           "8"
#         ],
#         "points": 89
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12743,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-21T00:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": "10:15",
#       "halftime": false,
#       "short": 2,
#       "long": "In Play"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Little Caesars Arena",
#       "city": "Detroit",
#       "state": "MI",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 9,
#         "name": "Denver Nuggets",
#         "nickname": "Nuggets",
#         "code": "DEN",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/3/35/Nuggets_de_Denver_2018.png/180px-Nuggets_de_Denver_2018.png"
#       },
#       "home": {
#         "id": 10,
#         "name": "Detroit Pistons",
#         "nickname": "Pistons",
#         "code": "DET",
#         "logo": "https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Logo_of_the_Detroit_Pistons.png/300px-Logo_of_the_Detroit_Pistons.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "27",
#           "29",
#           "25",
#           "3"
#         ],
#         "points": 84
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "23",
#           "32",
#           "24",
#           "8"
#         ],
#         "points": 87
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12744,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-21T00:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": "7:34",
#       "halftime": false,
#       "short": 2,
#       "long": "In Play"
#     },
#     "periods": {
#       "current": 4,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Capital One Arena",
#       "city": "Washington",
#       "state": "DC",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 21,
#         "name": "Milwaukee Bucks",
#         "nickname": "Bucks",
#         "code": "MIL",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/3/34/Bucks2015.png"
#       },
#       "home": {
#         "id": 41,
#         "name": "Washington Wizards",
#         "nickname": "Wizards",
#         "code": "WAS",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/archive/d/d6/20161212034849%21Wizards2015.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "31",
#           "39",
#           "34",
#           "13"
#         ],
#         "points": 117
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "27",
#           "38",
#           "37",
#           "8"
#         ],
#         "points": 110
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12745,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-21T01:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": "5:05",
#       "halftime": false,
#       "short": 2,
#       "long": "In Play"
#     },
#     "periods": {
#       "current": 2,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "United Center",
#       "city": "Chicago",
#       "state": "IL",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 20,
#         "name": "Miami Heat",
#         "nickname": "Heat",
#         "code": "MIA",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/1/1c/Miami_Heat_-_Logo.svg/1200px-Miami_Heat_-_Logo.svg.png"
#       },
#       "home": {
#         "id": 6,
#         "name": "Chicago Bulls",
#         "nickname": "Bulls",
#         "code": "CHI",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/d1/Bulls_de_Chicago_logo.svg/1200px-Bulls_de_Chicago_logo.svg.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "33",
#           "16",
#           "",
#           ""
#         ],
#         "points": 49
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "27",
#           "17",
#           "",
#           ""
#         ],
#         "points": 44
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12746,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-21T01:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": "6:16",
#       "halftime": false,
#       "short": 2,
#       "long": "In Play"
#     },
#     "periods": {
#       "current": 2,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Target Center",
#       "city": "Minneapolis",
#       "state": "MN",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 24,
#         "name": "New York Knicks",
#         "nickname": "Knicks",
#         "code": "NYK",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/3/34/Knicks_de_NY.png"
#       },
#       "home": {
#         "id": 22,
#         "name": "Minnesota Timberwolves",
#         "nickname": "Timberwolves",
#         "code": "MIN",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "28",
#           "17",
#           "",
#           ""
#         ],
#         "points": 45
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "31",
#           "17",
#           "",
#           ""
#         ],
#         "points": 48
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12747,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-21T01:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": "4:59",
#       "halftime": false,
#       "short": 2,
#       "long": "In Play"
#     },
#     "periods": {
#       "current": 2,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Smoothie King Center",
#       "city": "New Orleans",
#       "state": "LA",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 30,
#         "name": "Sacramento Kings",
#         "nickname": "Kings",
#         "code": "SAC",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/9/95/Kings_de_Sacramento_logo.svg/1200px-Kings_de_Sacramento_logo.svg.png"
#       },
#       "home": {
#         "id": 23,
#         "name": "New Orleans Pelicans",
#         "nickname": "Pelicans",
#         "code": "NOP",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "31",
#           "16",
#           "",
#           ""
#         ],
#         "points": 47
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "29",
#           "18",
#           "",
#           ""
#         ],
#         "points": 47
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   },
#   {
#     "id": 12748,
#     "league": "standard",
#     "season": 2023,
#     "date": {
#       "start": "2023-11-21T01:00:00.000Z",
#       "end": null,
#       "duration": null
#     },
#     "stage": 2,
#     "status": {
#       "clock": "4:20",
#       "halftime": false,
#       "short": 2,
#       "long": "In Play"
#     },
#     "periods": {
#       "current": 2,
#       "total": 4,
#       "endOfPeriod": false
#     },
#     "arena": {
#       "name": "Frost Bank Center",
#       "city": "San Antonio",
#       "state": "TX",
#       "country": null
#     },
#     "teams": {
#       "visitors": {
#         "id": 16,
#         "name": "LA Clippers",
#         "nickname": "Clippers",
#         "code": "LAC",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/d/d6/Los_Angeles_Clippers_logo_2010.png"
#       },
#       "home": {
#         "id": 31,
#         "name": "San Antonio Spurs",
#         "nickname": "Spurs",
#         "code": "SAS",
#         "logo": "https://upload.wikimedia.org/wikipedia/fr/0/0e/San_Antonio_Spurs_2018.png"
#       }
#     },
#     "scores": {
#       "visitors": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "33",
#           "20",
#           "",
#           ""
#         ],
#         "points": 53
#       },
#       "home": {
#         "win": 0,
#         "loss": 0,
#         "series": {
#           "win": 0,
#           "loss": 0
#         },
#         "linescore": [
#           "27",
#           "19",
#           "",
#           ""
#         ],
#         "points": 46
#       }
#     },
#     "officials": [],
#     "timesTied": null,
#     "leadChanges": null,
#     "nugget": null
#   }
# ]

# %% [markdown]
# ------
# Application Part
#
# Say I want to search a player in the NBA and get his stats for a given season

# %%
#Send a request to the API to get player info
conn.request("GET", "/players?name=Barrett", headers=headers)

res = conn.getresponse()
data = res.read()
# Decode bytes to string

# Parse the JSON string into a Python object
data_json = json.loads(data)
print(json.dumps(data_json['response'], indent=2))  # Pretty print JSON data
# Out:
# [
#   {
#     "id": 1846,
#     "firstname": "RJ",
#     "lastname": "Barrett",
#     "birth": {
#       "date": "2000-06-14",
#       "country": "Canada"
#     },
#     "nba": {
#       "start": 2019,
#       "pro": 2
#     },
#     "height": {
#       "feets": "6",
#       "inches": "6",
#       "meters": "1.98"
#     },
#     "weight": {
#       "pounds": "214",
#       "kilograms": "97.1"
#     },
#     "college": "Duke",
#     "affiliation": "Duke/Canada",
#     "leagues": {
#       "standard": {
#         "jersey": 9,
#         "active": true,
#         "pos": "F-G"
#       },
#       "vegas": {
#         "jersey": 9,
#         "active": true,
#         "pos": "G-F"
#       }
#     }
#   }
# ]

# %% [markdown]
# The API refers to players by their id for most of its queries.  The below code grabs the id of the played searched above but I would recommend the platform be able to search for a player by first and last name.

# %%
#Grab player ID
playerID=data_json['response'][0]['id']

# %%
conn.request("GET", f"/players/statistics?season=2023&id={playerID}", headers=headers)

res = conn.getresponse()
data = res.read()

data_json = json.loads(data)

# %% [markdown]
# Below code outputs the stats for the provided player for each game of the given season

# %%
data_json['response']
test = json.dumps(data_json['response'], indent=3)  # Pretty print JSON data
print(test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[393], line 1
# ----> 1 data_json['response']
#       2 test = json.dumps(data_json['response'], indent=3)  # Pretty print JSON data
#       3 print(test)
#
# KeyError: 'response'
